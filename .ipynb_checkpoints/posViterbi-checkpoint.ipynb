# %%
import numpy as np
import re

# %%
#read dataset function
def parse_dataset(file_path):
    dataset = []
    current_sentence = None
    dependacy = None

    with open(file_path, 'r', encoding='utf-8') as file:
        for line in file:
            line = line.strip()

            if line.startswith('# sent_id'):
                # Start of a new sentence
                if current_sentence:
                    current_sentence['dependacy'] = dependacy
                    dataset.append(current_sentence)
                current_sentence = {'sent_id': line.split('=')[1].strip(), 'text': ''}
            elif line.startswith('# text'):
                # Text of the sentence
                current_sentence['text'] = line.split('=')[1].strip()
                current_sentence['pos_tag'] = []
                dependacy = dict()
            elif line:
                # Details about each word in the sentence
                parts = line.split()
                if '-' in parts[0]:
                    continue

                head_value = parts[4] if parts[4] != '_' else None

                dependacy[parts[0]] = {
                        'original_word': parts[1],
                        'word': parts[2],
                        'pos': parts[3],
                        'head': int(head_value) if head_value is not None else None,
                        'dependency_relation': parts[5]
                    }
                current_sentence['pos_tag'].append(parts[3])

    # Append the last sentence to the dataset
    if current_sentence:
        current_sentence['dependacy'] = dependacy
        dataset.append(current_sentence)

    return dataset

# %%
file_path = 'train.txt'
parsed_dataset_train = parse_dataset(file_path)

# Print the parsed dataset for inspection
for sentence in parsed_dataset_train[:4]:
    print(sentence)
# Out:
# {'sent_id': 'GUM_academic_art-1', 'text': 'Aesthetic Appreciation and Spanish Art:', 'pos_tag': ['JJ', 'NN', 'CC', 'JJ', 'NN', ':'], 'dependacy': {'1': {'original_word': 'Aesthetic', 'word': 'aesthetic', 'pos': 'JJ', 'head': 2, 'dependency_relation': 'amod'}, '2': {'original_word': 'Appreciation', 'word': 'appreciation', 'pos': 'NN', 'head': 0, 'dependency_relation': 'root'}, '3': {'original_word': 'and', 'word': 'and', 'pos': 'CC', 'head': 5, 'dependency_relation': 'cc'}, '4': {'original_word': 'Spanish', 'word': 'Spanish', 'pos': 'JJ', 'head': 5, 'dependency_relation': 'amod'}, '5': {'original_word': 'Art', 'word': 'art', 'pos': 'NN', 'head': 2, 'dependency_relation': 'conj'}, '6': {'original_word': ':', 'word': ':', 'pos': ':', 'head': 2, 'dependency_relation': 'punct'}}}
# {'sent_id': 'GUM_academic_art-2', 'text': 'Insights from Eye-Tracking', 'pos_tag': ['NNS', 'IN', 'NN', 'HYPH', 'NN'], 'dependacy': {'1': {'original_word': 'Insights', 'word': 'insight', 'pos': 'NNS', 'head': 0, 'dependency_relation': 'root'}, '2': {'original_word': 'from', 'word': 'from', 'pos': 'IN', 'head': 5, 'dependency_relation': 'case'}, '3': {'original_word': 'Eye', 'word': 'eye', 'pos': 'NN', 'head': 5, 'dependency_relation': 'compound'}, '4': {'original_word': '-', 'word': '-', 'pos': 'HYPH', 'head': 3, 'dependency_relation': 'punct'}, '5': {'original_word': 'Tracking', 'word': 'tracking', 'pos': 'NN', 'head': 1, 'dependency_relation': 'nmod'}}}
# {'sent_id': 'GUM_academic_art-3', 'text': 'Claire Bailey-Ross claire.bailey-ross@port.ac.uk University of Portsmouth, United Kingdom', 'pos_tag': ['NNP', 'NNP', 'HYPH', 'NNP', 'NNP', 'NNP', 'IN', 'NNP', ',', 'NNP', 'NNP'], 'dependacy': {'1': {'original_word': 'Claire', 'word': 'Claire', 'pos': 'NNP', 'head': 0, 'dependency_relation': 'root'}, '2': {'original_word': 'Bailey', 'word': 'Bailey', 'pos': 'NNP', 'head': 1, 'dependency_relation': 'flat'}, '3': {'original_word': '-', 'word': '-', 'pos': 'HYPH', 'head': 4, 'dependency_relation': 'punct'}, '4': {'original_word': 'Ross', 'word': 'Ross', 'pos': 'NNP', 'head': 2, 'dependency_relation': 'flat'}, '5': {'original_word': 'claire.bailey-ross@port.ac.uk', 'word': 'claire.bailey-ross@port.ac.uk', 'pos': 'NNP', 'head': 1, 'dependency_relation': 'list'}, '6': {'original_word': 'University', 'word': 'University', 'pos': 'NNP', 'head': 1, 'dependency_relation': 'list'}, '7': {'original_word': 'of', 'word': 'of', 'pos': 'IN', 'head': 8, 'dependency_relation': 'case'}, '8': {'original_word': 'Portsmouth', 'word': 'Portsmouth', 'pos': 'NNP', 'head': 6, 'dependency_relation': 'nmod'}, '9': {'original_word': ',', 'word': ',', 'pos': ',', 'head': 11, 'dependency_relation': 'punct'}, '10': {'original_word': 'United', 'word': 'Unite', 'pos': 'NNP', 'head': 11, 'dependency_relation': 'amod'}, '11': {'original_word': 'Kingdom', 'word': 'Kingdom', 'pos': 'NNP', 'head': 1, 'dependency_relation': 'list'}}}
# {'sent_id': 'GUM_academic_art-4', 'text': 'Andrew Beresford a.m.beresford@durham.ac.uk Durham University, United Kingdom', 'pos_tag': ['NNP', 'NNP', 'NNP', 'NNP', 'NNP', ',', 'NNP', 'NNP'], 'dependacy': {'1': {'original_word': 'Andrew', 'word': 'Andrew', 'pos': 'NNP', 'head': 0, 'dependency_relation': 'root'}, '2': {'original_word': 'Beresford', 'word': 'Beresford', 'pos': 'NNP', 'head': 1, 'dependency_relation': 'flat'}, '3': {'original_word': 'a.m.beresford@durham.ac.uk', 'word': 'a.m.beresford@durham.ac.uk', 'pos': 'NNP', 'head': 1, 'dependency_relation': 'list'}, '4': {'original_word': 'Durham', 'word': 'Durham', 'pos': 'NNP', 'head': 5, 'dependency_relation': 'compound'}, '5': {'original_word': 'University', 'word': 'University', 'pos': 'NNP', 'head': 1, 'dependency_relation': 'list'}, '6': {'original_word': ',', 'word': ',', 'pos': ',', 'head': 8, 'dependency_relation': 'punct'}, '7': {'original_word': 'United', 'word': 'Unite', 'pos': 'NNP', 'head': 8, 'dependency_relation': 'amod'}, '8': {'original_word': 'Kingdom', 'word': 'Kingdom', 'pos': 'NNP', 'head': 1, 'dependency_relation': 'list'}}}

# %%
# get all the post tags
from collections import Counter

# Initialize a Counter to store the frequency of each POS tag
pos_tag_frequency = Counter()

# Iterate through the dataset to collect unique POS tags and their frequency counts
for sentence_data in parsed_dataset_train:
    pos_tags = sentence_data['pos_tag']
    pos_tag_frequency.update(pos_tags)

# %%
# Print the total number of unique POS tags
print("Total unique POS tags:", len(pos_tag_frequency))
# Print the unique POS tags and their frequency counts
print("Unique POS tags and their frequency counts:")
for tag, count in pos_tag_frequency.items():
    print(f"{tag}: {count}")
# Out:
# Total unique POS tags: 46
# Unique POS tags and their frequency counts:
# JJ: 2129
# NN: 4540
# CC: 1092
# :: 325
# NNS: 1599
# IN: 4204
# HYPH: 217
# NNP: 2819
# ,: 2209
# WRB: 126
# VBP: 596
# VB: 851
# .: 1758
# WDT: 189
# PRP: 1366
# DT: 2971
# VBZ: 699
# VBG: 487
# RB: 1272
# MD: 291
# PRP$: 453
# VBN: 816
# FW: 125
# SYM: 59
# VBD: 1041
# TO: 370
# RP: 89
# -LRB-: 525
# -RRB-: 524
# POS: 154
# CD: 1118
# EX: 43
# LS: 23
# JJR: 71
# RBR: 76
# WP$: 5
# JJS: 40
# PDT: 24
# ``: 124
# '': 126
# WP: 116
# NNPS: 103
# UH: 471
# RBS: 33
# GW: 1
# $: 1

# %%
# get text in a sentance
def get_text(sentence_data):
  return [ row['original_word'] for row in sentence_data['dependacy'].values()]

print(f"Original text {get_text(parsed_dataset_train[6])}")
print(f"Pos Tag {parsed_dataset_train[6]['pos_tag']}")
# Out:
# Original text ['How', 'do', 'people', 'look', 'at', 'and', 'experience', 'art', '?']
# Pos Tag ['WRB', 'VBP', 'NNS', 'VB', 'IN', 'CC', 'VB', 'NN', '.']

# %%
# get unique words
unique_words= set()
# Iterate through the dataset to collect unique POS tags
for sentence_data in parsed_dataset_train:
    words = get_text(sentence_data)
    unique_words.update(words)

# %%
# Print the total number of unique POS tags
print("Total unique POS tags:", len(unique_words))

# Print the unique POS tags
# print("Unique words:", unique_words)
# Out:
# Total unique POS tags: 6607

# %%
import collections
from collections import defaultdict

# %%
# transition matrix
def compute_transition_probabilities(parsed_dataset):
    # Initialize a dictionary to store transition counts
    transition_counts = defaultdict(int)

    # Count transitions in the dataset
    for sentence_data in parsed_dataset:
        pos_tags = sentence_data['pos_tag']
        for i in range(len(pos_tags) - 1):
            transition_counts[(pos_tags[i], pos_tags[i + 1])] += 1

    # Compute transition probabilities
    transition_probabilities = {transition: count / pos_tag_frequency[transition[0]] for transition, count in transition_counts.items()}

    return transition_probabilities

# %%
# emission matrix
def compute_emission_probabilities(parsed_dataset):
    # Initialize a dictionary to store emission counts
    emission_counts = defaultdict(int)

    # Count emissions in the dataset
    for sentence_data in parsed_dataset:
        pos_tags = sentence_data['pos_tag']
        words = get_text(sentence_data)   # [token_data['pos'] for token_data in sentence_data.values() if isinstance(token_data, dict)]
        for pos_tag, word in zip(pos_tags, words):
            emission_counts[(pos_tag, word)] += 1

    # Compute emission probabilities
    emission_probabilities = {emission: (count + 1) / (pos_tag_frequency[emission[0]] + len(unique_words))  for emission, count in emission_counts.items()}
    # emission_probabilities = {emission: count / pos_tag_frequency[emission[0]] for emission, count in emission_counts.items()}

    return emission_probabilities

# %%
# start transition matrix
def compute_start_probabilities(parsed_dataset):
    # Initialize a dictionary to store start counts
    start_counts = defaultdict(int)

    # Count starts in the dataset
    for sentence_data in parsed_dataset:
        start_tag = sentence_data['pos_tag'][0]
        start_counts[start_tag] += 1

    # Compute start probabilities
    total_sentences = len(parsed_dataset)
    start_probabilities = {tag: count / total_sentences for tag, count in start_counts.items()}

    return start_probabilities

# %%
# generating all the matrix
transition_probabilities = compute_transition_probabilities(parsed_dataset_train)
emission_probabilities = compute_emission_probabilities(parsed_dataset_train)
start_probabilities = compute_start_probabilities(parsed_dataset_train)

# %%
# sum(emission_probabilities.values()), sum(transition_probabilities.values()), sum(start_probabilities.values())

# %%
# Print the computed probabilities
print("Transition Probabilities:", transition_probabilities)
print("Emission Probabilities:", emission_probabilities)
print("Start Probabilities:", start_probabilities)
# Out:
# Transition Probabilities: {('JJ', 'NN'): 0.44387036167214655, ('NN', 'CC'): 0.04889867841409692, ('CC', 'JJ'): 0.09981684981684982, ('NN', ':'): 0.011674008810572687, ('NNS', 'IN'): 0.2926829268292683, ('IN', 'NN'): 0.12702188392007613, ('NN', 'HYPH'): 0.01629955947136564, ('HYPH', 'NN'): 0.2903225806451613, ('NNP', 'NNP'): 0.29478538488825823, ('NNP', 'HYPH'): 0.01596310748492373, ('HYPH', 'NNP'): 0.2350230414746544, ('NNP', 'IN'): 0.10322809506917346, ('IN', 'NNP'): 0.1439105613701237, ('NNP', ','): 0.13338063142958495, (',', 'NNP'): 0.10819375282933454, ('WRB', 'VBP'): 0.031746031746031744, ('VBP', 'NNS'): 0.028523489932885907, ('NNS', 'VB'): 0.0031269543464665416, ('VB', 'IN'): 0.1245593419506463, ('IN', 'CC'): 0.0028544243577545195, ('CC', 'VB'): 0.02197802197802198, ('VB', 'NN'): 0.07403055229142186, ('NN', '.'): 0.11211453744493392, ('WDT', 'NNS'): 0.042328042328042326, ('IN', 'JJ'): 0.08705994291151284, ('JJ', 'NNS'): 0.2235791451385627, ('NNS', 'VBP'): 0.07066916823014384, ('VBP', 'PRP'): 0.09395973154362416, ('PRP', 'VB'): 0.030014641288433383, ('IN', '.'): 0.0035680304471931495, ('VBP', 'NN'): 0.031879194630872486, ('NN', 'NNS'): 0.03986784140969163, ('VB', 'DT'): 0.20799059929494712, ('DT', 'NN'): 0.4537192864355436, ('NN', 'IN'): 0.28348017621145377, ('IN', 'WRB'): 0.0028544243577545195, ('WRB', 'NNS'): 0.047619047619047616, ('VBP', 'IN'): 0.087248322147651, ('IN', 'NNS'): 0.04210275927687916, ('NNS', '.'): 0.12695434646654158, ('NN', 'NN'): 0.09449339207048459, ('NN', 'VBZ'): 0.04691629955947137, ('VBZ', 'DT'): 0.20743919885550788, ('DT', 'JJ'): 0.21305957590037025, ('NN', ','): 0.12951541850220263, (',', 'VBG'): 0.028972385694884563, ('VBG', 'NNS'): 0.09034907597535935, (',', 'NN'): 0.03802625622453599, ('HYPH', 'VBG'): 0.03225806451612903, ('VBG', ','): 0.03285420944558522, (',', 'CC'): 0.14622000905387053, ('CC', 'NN'): 0.1282051282051282, ('RB', ','): 0.1360062893081761, (',', 'DT'): 0.09551833408782254, ('NN', 'PRP'): 0.00947136563876652, ('PRP', 'VBZ'): 0.10395314787701318, ('VBZ', 'CC'): 0.00715307582260372, ('CC', 'DT'): 0.10622710622710622, ('DT', 'NNS'): 0.07707842477280377, ('IN', 'RB'): 0.012131303520456709, ('RB', 'VBG'): 0.026729559748427674, ('VBG', 'DT'): 0.21765913757700206, ('NN', 'MD'): 0.014317180616740088, ('MD', 'VB'): 0.7250859106529209, ('IN', 'PRP$'): 0.0532825880114177, ('PRP$', 'NN'): 0.5496688741721855, ('CC', 'RB'): 0.07967032967032966, ('RB', 'PRP$'): 0.0015723270440251573, ('PRP$', 'JJ'): 0.22075055187637968, ('NN', 'VBG'): 0.007048458149779736, ('VBG', 'IN'): 0.14989733059548255, ('IN', 'DT'): 0.3332540437678401, ('NN', 'NNP'): 0.015198237885462556, ('NNP', 'NNS'): 0.0046115643845335225, ('DT', 'NNP'): 0.09289801413665433, ('NNP', 'VBZ'): 0.012415750266051791, ('JJ', 'NNP'): 0.016439643024894316, ('NNP', 'NN'): 0.02021993614757006, ('NN', 'VBN'): 0.01013215859030837, ('VBN', 'FW'): 0.0012254901960784314, ('FW', 'FW'): 0.352, ('FW', 'IN'): 0.056, ('HYPH', 'VBN'): 0.15668202764976957, ('VBN', 'NNS'): 0.030637254901960783, ('NN', 'VBP'): 0.005947136563876652, ('VBP', 'VBN'): 0.10906040268456375, ('VBN', 'IN'): 0.46568627450980393, ('NNS', 'CC'): 0.06316447779862414, ('CC', 'NNS'): 0.045787545787545784, ('JJ', 'SYM'): 0.0009394081728511038, ('SYM', 'JJ'): 0.0847457627118644, ('NNS', ','): 0.15134459036898062, ('VBZ', 'VBN'): 0.12160228898426323, ('VBN', 'VBN'): 0.04411764705882353, ('CC', 'IN'): 0.07509157509157509, (',', 'PRP'): 0.10502489814395655, ('PRP', 'VBP'): 0.22986822840409957, ('NNS', 'NN'): 0.0050031269543464665, ('IN', 'VBG'): 0.03425309229305423, ('NN', 'VBD'): 0.025330396475770924, ('VBD', 'TO'): 0.040345821325648415, ('TO', 'VB'): 0.9378378378378378, ('JJ', 'VBN'): 0.0028182245185533112, ('VBN', 'NN'): 0.09926470588235294, ('PRP', 'MD'): 0.0841874084919473, ('CC', 'PRP$'): 0.023809523809523808, ('VBZ', 'RP'): 0.010014306151645207, ('RP', 'VBN'): 0.011235955056179775, (',', 'JJ'): 0.027161611588954276, ('NNS', 'TO'): 0.015634771732332707, ('VB', ','): 0.03290246768507638, ...
# Emission Probabilities: {('JJ', 'Aesthetic'): 0.00022893772893772894, ('NN', 'Appreciation'): 0.00017942047187584104, ('CC', 'and'): 0.10455903364073256, ('JJ', 'Spanish'): 0.0011446886446886447, ('NN', 'Art'): 0.00017942047187584104, (':', ':'): 0.010530871321407963, ('NNS', 'Insights'): 0.00024372410431391665, ('IN', 'from'): 0.011099805753399316, ('NN', 'Eye'): 0.00017942047187584104, ('HYPH', '-'): 0.03179953106682298, ('NN', 'Tracking'): 0.00017942047187584104, ('NNP', 'Claire'): 0.00031826861871419476, ('NNP', 'Bailey'): 0.0002121790791427965, ('NNP', 'Ross'): 0.0002121790791427965, ('NNP', 'claire.bailey-ross@port.ac.uk'): 0.0002121790791427965, ('NNP', 'University'): 0.003713133884998939, ('IN', 'of'): 0.09481084081028582, ('NNP', 'Portsmouth'): 0.0002121790791427965, (',', ','): 0.25045372050816694, ('NNP', 'United'): 0.0013791640144281774, ('NNP', 'Kingdom'): 0.0005304476978569913, ('NNP', 'Andrew'): 0.0002121790791427965, ('NNP', 'Beresford'): 0.00031826861871419476, ('NNP', 'a.m.beresford@durham.ac.uk'): 0.0002121790791427965, ('NNP', 'Durham'): 0.0005304476978569913, ('NNP', 'Daniel'): 0.002015701251856567, ('NNP', 'Smith'): 0.0002121790791427965, ('NNP', 'daniel.smith2@durham.ac.uk'): 0.0002121790791427965, ('NNP', 'Warwick'): 0.0002121790791427965, ('NNP', 'c.l.h.warwick@durham.ac.uk'): 0.0002121790791427965, ('WRB', 'How'): 0.0014852220406950838, ('VBP', 'do'): 0.006802721088435374, ('NNS', 'people'): 0.0028028271996100415, ('VB', 'look'): 0.0013408420488066506, ('IN', 'at'): 0.015354731292202387, ('VB', 'experience'): 0.0005363368195226602, ('NN', 'art'): 0.0009868125953171258, ('.', '?'): 0.01625821876867902, ('WDT', 'Which'): 0.0008828722778104767, ('NNS', 'elements'): 0.0008530343650987082, ('JJ', 'specific'): 0.0016025641025641025, ('NNS', 'artworks'): 0.0010967584694126249, ('PRP', 'they'): 0.006522011789790543, ('VB', 'focus'): 0.0002681684097613301, ('IN', 'on'): 0.016649708630098972, ('VBP', 'Do'): 0.0006941552131056504, ('NN', 'museum'): 0.0006279716515654436, ('NNS', 'labels'): 0.00024372410431391665, ('VB', 'have'): 0.006436041834271922, ('DT', 'an'): 0.010022969304656505, ('NN', 'impact'): 0.0005382614156275231, ('WRB', 'how'): 0.004158621713946235, ('VBP', 'look'): 0.0005553241704845203, ('DT', 'The'): 0.014199206514930047, ('NN', 'viewing'): 0.00017942047187584104, ('NN', 'experience'): 0.0008971023593792052, ('VBZ', 'is'): 0.036955926635641935, ('DT', 'a'): 0.061912716642305285, ('JJ', 'complex'): 0.0004578754578754579, ('NN', 'one'): 0.002063335426572172, ('VBG', 'involving'): 0.00042289258528333803, ('NNS', 'issues'): 0.000365586156470875, ('NN', 'perception'): 0.00017942047187584104, ('NN', 'attention'): 0.0016147842468825693, ('NN', 'memory'): 0.0003588409437516821, ('NN', 'decision'): 0.0004485511796896026, ('VBG', 'making'): 0.0009867493656611221, ('NN', 'affect'): 0.00017942047187584104, ('NN', 'emotion'): 0.00017942047187584104, ('.', '.'): 0.19318589360430363, ('RB', 'Thus'): 0.001523035918263739, ('DT', 'the'): 0.16297765713092505, ('NN', 'time'): 0.0036781196734547413, ('PRP', 'it'): 0.02483381412266399, ('VBZ', 'takes'): 0.0012318642211880647, ('NNS', 'ways'): 0.0013404825737265416, ('RB', 'visually'): 0.00038075897956593474, ('VBG', 'exploring'): 0.000563856780377784, ('NN', 'artwork'): 0.0004485511796896026, ('MD', 'can'): 0.01072774717309365, ('VB', 'inform'): 0.00040225261464199515, ('IN', 'about'): 0.002497456294514846, ('PRP$', 'its'): 0.006373937677053824, ('NN', 'relevance'): 0.0003588409437516821, ('NN', 'interestingness'): 0.00017942047187584104, ('RB', 'even'): 0.001523035918263739, ('JJ', 'aesthetic'): 0.0005723443223443224, ('NN', 'appeal'): 0.00017942047187584104, ('DT', 'This'): 0.0049070787220714136, ('NN', 'paper'): 0.0007176818875033642, ('VBZ', 'describes'): 0.0004106214070626882, ('JJ', 'collaborative'): 0.00034340659340659343, ('NN', 'pilot'): 0.0005382614156275231, ('NN', 'project'): 0.0010765228312550462, ('VBG', 'focusing'): 0.000563856780377784, ('JJ', 'uniqu ...
# Start Probabilities: {'JJ': 0.0385, 'NNS': 0.011, 'NNP': 0.0995, 'WRB': 0.0095, 'WDT': 0.003, 'VBP': 0.007, 'DT': 0.1075, 'RB': 0.083, 'IN': 0.141, 'PRP': 0.1615, 'PRP$': 0.027, 'LS': 0.0075, 'VBG': 0.0085, 'RBR': 0.003, 'JJS': 0.0015, 'CD': 0.019, 'CC': 0.052, 'WP': 0.009, 'PDT': 0.002, 'NN': 0.0315, 'VBN': 0.0065, 'TO': 0.0035, 'EX': 0.0065, 'NNPS': 0.001, 'VB': 0.013, 'UH': 0.127, 'VBZ': 0.0075, 'JJR': 0.001, '``': 0.0025, 'FW': 0.003, '-LRB-': 0.0005, 'VBD': 0.003, 'RBS': 0.001, 'MD': 0.0015}

# %%
len(transition_probabilities), len(emission_probabilities), len(start_probabilities)
# Out:
# (948, 7201, 34)

# %%
# reading text file:
file_path = 'test.txt'
parsed_dataset_test = parse_dataset(file_path)

# Print the parsed dataset for inspection
for sentence in parsed_dataset_test[:4]:
    print(sentence)
# Out:
# {'sent_id': 'GUM_academic_discrimination-1', 'text': 'The prevalence of discrimination across racial groups in contemporary America:', 'pos_tag': ['DT', 'NN', 'IN', 'NN', 'IN', 'JJ', 'NNS', 'IN', 'JJ', 'NNP', ':'], 'dependacy': {'1': {'original_word': 'The', 'word': 'the', 'pos': 'DT', 'head': 2, 'dependency_relation': 'det'}, '2': {'original_word': 'prevalence', 'word': 'prevalence', 'pos': 'NN', 'head': 0, 'dependency_relation': 'root'}, '3': {'original_word': 'of', 'word': 'of', 'pos': 'IN', 'head': 4, 'dependency_relation': 'case'}, '4': {'original_word': 'discrimination', 'word': 'discrimination', 'pos': 'NN', 'head': 2, 'dependency_relation': 'nmod'}, '5': {'original_word': 'across', 'word': 'across', 'pos': 'IN', 'head': 7, 'dependency_relation': 'case'}, '6': {'original_word': 'racial', 'word': 'racial', 'pos': 'JJ', 'head': 7, 'dependency_relation': 'amod'}, '7': {'original_word': 'groups', 'word': 'group', 'pos': 'NNS', 'head': 2, 'dependency_relation': 'nmod'}, '8': {'original_word': 'in', 'word': 'in', 'pos': 'IN', 'head': 10, 'dependency_relation': 'case'}, '9': {'original_word': 'contemporary', 'word': 'contemporary', 'pos': 'JJ', 'head': 10, 'dependency_relation': 'amod'}, '10': {'original_word': 'America', 'word': 'America', 'pos': 'NNP', 'head': 2, 'dependency_relation': 'nmod'}, '11': {'original_word': ':', 'word': ':', 'pos': ':', 'head': 2, 'dependency_relation': 'punct'}}}
# {'sent_id': 'GUM_academic_discrimination-2', 'text': 'Results from a nationally representative sample of adults', 'pos_tag': ['NNS', 'IN', 'DT', 'RB', 'JJ', 'NN', 'IN', 'NNS'], 'dependacy': {'1': {'original_word': 'Results', 'word': 'result', 'pos': 'NNS', 'head': 0, 'dependency_relation': 'root'}, '2': {'original_word': 'from', 'word': 'from', 'pos': 'IN', 'head': 6, 'dependency_relation': 'case'}, '3': {'original_word': 'a', 'word': 'a', 'pos': 'DT', 'head': 6, 'dependency_relation': 'det'}, '4': {'original_word': 'nationally', 'word': 'nationally', 'pos': 'RB', 'head': 5, 'dependency_relation': 'advmod'}, '5': {'original_word': 'representative', 'word': 'representative', 'pos': 'JJ', 'head': 6, 'dependency_relation': 'amod'}, '6': {'original_word': 'sample', 'word': 'sample', 'pos': 'NN', 'head': 1, 'dependency_relation': 'nmod'}, '7': {'original_word': 'of', 'word': 'of', 'pos': 'IN', 'head': 8, 'dependency_relation': 'case'}, '8': {'original_word': 'adults', 'word': 'adult', 'pos': 'NNS', 'head': 6, 'dependency_relation': 'nmod'}}}
# {'sent_id': 'GUM_academic_discrimination-3', 'text': 'Introduction.', 'pos_tag': ['NN', '.'], 'dependacy': {'1': {'original_word': 'Introduction', 'word': 'introduction', 'pos': 'NN', 'head': 0, 'dependency_relation': 'root'}, '2': {'original_word': '.', 'word': '.', 'pos': '.', 'head': 1, 'dependency_relation': 'punct'}}}
# {'sent_id': 'GUM_academic_discrimination-4', 'text': 'Personal experiences of discrimination and bias have been the focus of much social science research. [1 - 3]', 'pos_tag': ['JJ', 'NNS', 'IN', 'NN', 'CC', 'NN', 'VBP', 'VBN', 'DT', 'NN', 'IN', 'JJ', 'JJ', 'NN', 'NN', '.', '-LRB-', 'CD', 'SYM', 'CD', '-RRB-'], 'dependacy': {'1': {'original_word': 'Personal', 'word': 'personal', 'pos': 'JJ', 'head': 2, 'dependency_relation': 'amod'}, '2': {'original_word': 'experiences', 'word': 'experience', 'pos': 'NNS', 'head': 10, 'dependency_relation': 'nsubj'}, '3': {'original_word': 'of', 'word': 'of', 'pos': 'IN', 'head': 4, 'dependency_relation': 'case'}, '4': {'original_word': 'discrimination', 'word': 'discrimination', 'pos': 'NN', 'head': 2, 'dependency_relation': 'nmod'}, '5': {'original_word': 'and', 'word': 'and', 'pos': 'CC', 'head': 6, 'dependency_relation': 'cc'}, '6': {'original_word': 'bias', 'word': 'bias', 'pos': 'NN', 'head': 4, 'dependency_relation': 'conj'}, '7': {'original_word': 'have', 'word': 'have', 'pos': 'VBP', 'head': 10, 'dependency_relation': 'aux'}, '8': {'original_word': 'been', 'word': 'be', 'pos': 'VBN', 'head': 10, 'dependency_relation': 'cop'}, '9': {'original_word': 'the', 'word': 'the', 'pos': 'DT', 'head': 10, 'dependency_relation': 'det'}, '10': {'original_word': 'focus', 'word': 'focus', 'pos': 'NN', 'head': 0, 'dependency_relation': 'root'}, '11': {'original_word': 'of', 'word': 'of', 'pos': 'IN', 'head': 15, 'dependency_relation': 'case'}, '12': {'original_word': 'much', 'word': 'much', 'pos': 'JJ', 'head': 15, 'dependency_relation': 'dep'}, '13': {'original_word': 'social', 'word': 'social', 'pos': 'JJ', 'head': 14, 'dependency_relation': 'amod'}, '14': {'original_word': 'science', 'word': 'science', 'pos': 'NN', 'head': 15, 'dependency_relation': 'compound'}, '15': {'original_word': 'research', 'word': 'research', 'pos': 'NN', 'head': 10, 'dependency_relation': 'nmod'}, '16': {'original_word': '.', 'word': '.', 'pos': '.', 'head': 10, 'dependency_relation': 'punct'}, '17': {'original_word': '[', 'word': '[', 'pos': '-LRB-', 'head': 18, 'dependency_relation': 'punct'}, '18': {'original_word': '1', 'word': '1', 'pos': 'CD', 'head': 10, 'dependency_relation': 'dep'}, '19': {'original_word': '-', 'word': '-', 'pos': 'SYM', 'head': 20, 'dependency_relation': 'case'}, '20': {'original_word': '3', 'word': '3', 'pos': 'CD', 'head': 18, 'dependency_relation': 'nmod'}, '21': {'original_word': ']', 'word': ']', 'pos': '-RRB-', 'head': 18, 'dependency_relation': 'punct'}}}

# %%
import math
# viterbi algo funtion which return best pos tag path and smooth_words (unseen words in training)
def viterbi_algorithm(sentence_data, transition_probabilities, emission_probabilities, start_probabilities):
    pos_tags = pos_tag_frequency.keys()  # sentence_data['pos_tag']
    words = get_text(sentence_data)
    value_for_unseen_transition = 1e-10
    value_for_unseen_emission = (1/len(unique_words))   # 1e-10
    smooth_words = set()

    # Initialize the Viterbi matrix
    viterbi_matrix = [{} for _ in range(len(words))]
    backpointer_matrix = [{} for _ in range(len(words))]

    # Initialization step
    for tag in pos_tags:
        start_prob = start_probabilities.get(tag, value_for_unseen_transition)  # Use a default value, e.g., 1e-10
        emission_prob = emission_probabilities.get((tag, words[0]), value_for_unseen_emission)  # Use a default value, e.g., 1e-10
        viterbi_matrix[0][tag] = math.log(start_prob) + math.log(emission_prob)

    # Recursion and termination steps
    for t in range(1, len(words)):
        max_emission_prob = value_for_unseen_emission
        # if words[t] not in unique_words:
        #     smooth_words.add(words[t])
             # print(words[t])
       

        for current_tag in pos_tags:
            max_prob = float('-inf')
            best_prev_tag = None

            for prev_tag in pos_tags:
                transition_prob = transition_probabilities.get((prev_tag, current_tag), value_for_unseen_transition)  
                emission_prob = emission_probabilities.get((current_tag, words[t]), value_for_unseen_emission)  

                current_prob = viterbi_matrix[t - 1][prev_tag] + math.log(transition_prob) + math.log(emission_prob)

                if current_prob > max_prob:
                    max_prob = current_prob
                    best_prev_tag = prev_tag

                if max_emission_prob < emission_prob:
                    max_emission_prob = emission_prob 

            viterbi_matrix[t][current_tag] = max_prob
            backpointer_matrix[t][current_tag] = best_prev_tag
            
        if max_emission_prob == value_for_unseen_emission:
            smooth_words.add(words[t])

    # Find the best path
    best_path = []
    max_prob_last_tag = max(viterbi_matrix[-1].values())
    for tag, prob in viterbi_matrix[-1].items():
        if prob == max_prob_last_tag:
            best_last_tag = tag
            break

    best_path.append(best_last_tag)
    for t in range(len(words) - 1, 0, -1):
        best_prev_tag = backpointer_matrix[t][best_last_tag]
        best_path.insert(0, best_prev_tag)
        best_last_tag = best_prev_tag

    return best_path, smooth_words

# %%
# calculate accuracy
def calculate_accuracy(true_tag, pred_tag):
    print(len(true_tag), len(pred_tag))
    if len(true_tag) != len(pred_tag):
        raise ValueError("Input lists must have the same length")

    correct_predictions = sum(1 for true, pred in zip(true_tag, pred_tag) if true == pred)
    total_predictions = len(true_tag)

    accuracy = correct_predictions / total_predictions

    return accuracy

# %%
from sklearn import metrics
# calculate all other metrics
def calculate_metrics(true_tags, pred_tags):
    # Calculate accuracy
    accuracy = metrics.accuracy_score(true_tags, pred_tags)

    # Calculate precision, recall, and F1-score
    precision = metrics.precision_score(true_tags, pred_tags, average='weighted', zero_division=1)
    recall = metrics.recall_score(true_tags, pred_tags, average='weighted', zero_division=1)
    f1_score = metrics.f1_score(true_tags, pred_tags, average='weighted', zero_division=1)

    return accuracy, precision, recall, f1_score

# %%
# output file write 
def write_tsv(output_file_path):
    with open(output_file_path, "w", encoding='utf-8') as output_file:
        # Write the header
        output_file.write("sent_id\ttoken_number\tword\tpredicted_POS_tag\n")
    
        # Write the predictions
        for sent_id, word, pred_tag in predictions_output:
            for i in range(len(pred_tag)):
                output_file.write(f"{sent_id}\t{i}\t{word[i]}\t{pred_tag[i]}\n")
    
        output_file.close()
        print(f"Predictions saved to {output_file_path}")

# %% [markdown]
# ## on Training

# %%
true_tags = []
pred_tags = []
# Initialize a list to store the predictions
predictions_output = []
unseen_words = []

# %%
# Apply Viterbi algorithm to each sentence in the train dataset
for sentence_data_train in parsed_dataset_train:
    best_path_train, unseen_word = viterbi_algorithm(sentence_data_train, transition_probabilities, emission_probabilities, start_probabilities)
    # print(f"Sentence: {sentence_data_train['text']}")
    # print(f"Original POS Tags: {sentence_data_train['pos_tag']}")
    # print(f"Predicted POS Tags: {best_path_train}\n")


    true_tags.extend(sentence_data_train['pos_tag'])
    pred_tags.extend(best_path_train)
    unseen_words.extend(unseen_word)

    # Save predictions to the list
    predictions_output.append((sentence_data_train['sent_id'], get_text(sentence_data_train), best_path_train))

# %%
accuracy = calculate_accuracy(true_tags, pred_tags)
print(f"Training Accuracy: {accuracy * 100:.2f}%")
# Out:
# 36271 36271
# Training Accuracy: 80.44%

# %%
accuracy, precision, recall, f1_score = calculate_metrics(true_tags, pred_tags)
print(f"Accuracy: {accuracy:.4f}")
print(f"Precision: {precision:.4f}")
print(f"Recall: {recall:.4f}")
print(f"F1-score: {f1_score:.4f}")
# Out:
# Accuracy: 0.8044
# Precision: 0.8204
# Recall: 0.8044
# F1-score: 0.7939

# %%
print(f"trains smooth words {len(unseen_words)} should be 0")
# Out:
# trains smooth words 0 should be 0

# %%
# Save the predictions to a file
output_file_path = "viterbi_predictions_train.tsv"
write_tsv(output_file_path)
# Out:
# Predictions saved to viterbi_predictions_train.tsv

# %% [markdown]
# ## on Testing

# %%
true_tags = []
pred_tags = []
# Initialize a list to store the predictions
predictions_output = []
smooth_words = set()

# %%
# Apply Viterbi algorithm to each sentence in the test dataset
for sentence_data_test in parsed_dataset_test:
    best_path_test , smooth_word = viterbi_algorithm(sentence_data_test, transition_probabilities, emission_probabilities, start_probabilities)
    # print(f"Sentence: {sentence_data_test['text']}")
    # print(f"Original POS Tags: {sentence_data_test['pos_tag']}")
    # print(f"Predicted POS Tags: {best_path_test}\n")


    true_tags.extend(sentence_data_test['pos_tag'])
    pred_tags.extend(best_path_test)

    # Save predictions to the list
    predictions_output.append((sentence_data_test['sent_id'], get_text(sentence_data_test), best_path_test))
    smooth_words.update(smooth_word)

# %%
accuracy = calculate_accuracy(true_tags, pred_tags)
print(f"Test Accuracy: {accuracy * 100:.2f}%")
# Out:
# 2180 2180
# Test Accuracy: 68.30%

# %%
accuracy, precision, recall, f1_score = calculate_metrics(true_tags, pred_tags)
print(f"Accuracy: {accuracy:.4f}")
print(f"Precision: {precision:.4f}")
print(f"Recall: {recall:.4f}")
print(f"F1-score: {f1_score:.4f}")
# Out:
# Accuracy: 0.6830
# Precision: 0.7245
# Recall: 0.6830
# F1-score: 0.6580

# %%
# Save the predictions to a file
output_file_path = "viterbi_predictions_test.tsv"
write_tsv(output_file_path)
# Out:
# Predictions saved to viterbi_predictions_test.tsv

# %%
unique_words_test= set()
# Iterate through the dataset to collect unique POS tags
for sentence_data in parsed_dataset_test:
    words = get_text(sentence_data)
    unique_words_test.update(words)

# %%
# Print the total number of unique POS tags
print("Total unique words:", len(unique_words_test))

# Print the unique POS tags
# print("Unique words:", unique_words_test)
# Out:
# Total unique words: 764

# %%
print(f"test smooth words {len(smooth_words)}")
print(smooth_words)
# Out:
# test smooth words 260
# {'Pacific', 'estimating', 'Basse', 'bearing', 'urban', 'Fogny', 'options', 'Guinea', '1904', 'svy', 'adjusted', 'wealth', 'varieties', 'Gulapaoray', 'ITS', 'neighbouring', 'preserve', 'eds.', 'Lewis', 'briefly', '-ʒæk', 'Bajjat', 'Dakar', 'policy', 'absorbing', 'discriminatory', '1873', 'Gambia', 'strategy', 'Eegimaa', 'prevention', 'underpin', 'homeland', 'ISO', 'refer', 'Smetana', 'Fennig', 'worldwide', 'Palmeri', 'codes', 'rooted', 'race', 'endangered', 'capturing', 'Brin', 'Gújjolaay', 'cohabit', 'idiom', 'NEIGHBOURS', 'Moravia', 'exploratory', 'speakers', 'bivariate', '1841', 'rare', 'Bourofaye', 'recreation', 'underpinnings', 'Jóola', 'section', 'counts', 'analysed', 'facing', 'logic', '74', 'Essil', 'African', 'Kujireray', 'approximate', 'generations', 'discrimination', 'species', 'Gibbons', 'suite', 'classified', 'Bayot', 'Black', 'noninteger', 'respondent', 'competition', 'Pearson', '§', 'transmission', 'migrant', 'build', 'implement', 'phylum', 'd(ə)ˈvɔːrʒɑːk', 'EEGIMAA', 'income', 'color', 'minority', 'beyond', 'north', 'Djibonker', 'Bassène', 'Composition', 'disability', 'Romantic', 'transcription', 'outside', 'weighted', 'villages', 'occurrence', 'appreciable', 'Hispanic', 'collapsed', 'Banjal', 'ˈlɛopolt', 'west', 'select', 'points', 'independence', 'respects', 'violin', 'conscious', 'Congo', 'workplace', 'THEIR', 'calculations', 'Kessler', 'musical', 'mainly', '11,200', 'Austrian', 'Senegal', 'Kamobeul', 'sex', 'Djilapaor', 'stratification', 'trainings', 'similarity', 'employing', 'Gazio', 'Seleki', 'spelling', 'referred', 'declining', 'influences', 'Kaasa', 'respondents', 'assumption', 'category', 'bsl', 'Mof-Ávvi', 'Dvořák', '2005-981', 'Butam', 'pattern', 'arrow', 'Islander', 'Gubëeher', 'symphonic', 'bordered', 'apt', 'exclusive', 'composer', 'estimates', 'River', '1874', 'theorists', 'Stata', 'Scott', 'distribution', 'SPEAKERS', 'Rao', 'Bissau', 'mixed', 'fullest', 'Ethnologue', 'mutually', 'coincides', 'nationally', 'peninsula', 'reduce', 'demographic', 'folk', 'dichotomously', 'adjustments', 'usual', 'Decree', '1995', 'Ziguinchor', 'Sapir', 'Húluf', 'Kusiilay', 'orthography', 'Bohemia', 'Ésuulaaluʔ', 'Gufiñamay', 'speech', 'Atlantic', 'analytical', 'Czech', 'Bedřich', 'code', 'examined', 'courtesy', 'river', 'attrition', 'Niger', 'administrative', 'd(ə)-VOR-zha(h)k', 'Prague', 'commands', 'ritual', 'adults', 'Symphony', 'symphonies', 'interviewed', 'differential', 'Kuluunaay', 'GUJJOLAAY', 'Djifanghor', 'proportions', 'rediscovered', 'subtracting', 'recoded', 'Gusiilay', 'prevalence', 'bqj', '76', 'Thionk', 'separates', 'peoples', 'questionnaire', 'kingdom', 'rhythms', 'Baïnounk', 'settings', 'sampling', 'shade', 'seeks', 'neurobiological', 'Búluf', 'statistic', 'ˈdvor̝aːk', 'Bandial', 'nationalist', 'east', 'Bolon', 'recommendation', 'clustering', '639-3', 'Native', 'steps', '7,000', 'adverse', 'Indian', 'BAK', 'discriminated', 'examine', 'unreturned', 'ˈantoɲiːn', 'Sállagi', 'Afiniam', 'corrects', 'χ2', 'push', 'Casamance'}
